# %% [markdown]
# <a href="https://colab.research.google.com/github/ahaseebai/Complete-Machine-Learning-with-Abdul-Haseeb-Memon/blob/main/01_Excel_to_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Dataset=pd.read_csv("patient.csv")
Dataset
# Out:
#     Age (X)  Blood Pressure (Y)
# 0      25.0               120.0
# 1      30.0               125.0
# 2      35.0               130.0
# 3      40.0                 NaN
# 4      45.0               135.0
# 5      50.0               140.0
# 6      55.0               145.0
# 7      60.0                 NaN
# 8      65.0               150.0
# 9      70.0               155.0
# 10     75.0               160.0
# 11     80.0               165.0
# 12     85.0               170.0
# 13     90.0                90.0
# 14     95.0               175.0
# 15    100.0               180.0
# 16    105.0               250.0
# 17    110.0               185.0
# 18      NaN               160.0
# 19    120.0               190.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# Dataset['Age (X)'].plot(kind='hist', bins=20, title='Age (X)')
# ...

# %% [markdown]
# # **Statistics of Dataset:**

# %%
Dataset.describe()
# Out:
#           Age (X)  Blood Pressure (Y)
# count   19.000000           18.000000
# mean    70.263158          156.944444
# std     28.600393           34.476714
# min     25.000000           90.000000
# 25%     47.500000          136.250000
# 50%     70.000000          157.500000
# 75%     92.500000          173.750000
# max    120.000000          250.000000

# %% [markdown]
# # **structure of Dataset:(rows & columns)**

# %%
Dataset.shape
# Out:
# (20, 2)

# %% [markdown]
# # **Datatypes of Dataset: (Data Nature)**

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age (X)             19 non-null     float64
#  1   Blood Pressure (Y)  18 non-null     float64
# dtypes: float64(2)
# memory usage: 452.0 bytes

# %% [markdown]
# # **Dimensions of Dataset:**

# %%
Dataset.ndim
# Out:
# 2

# %% [markdown]
# # **Dimensions of Columns:**

# %%
Dataset["Age (X)"].ndim
# Out:
# 1

# %%
Dataset[["Age (X)"]].ndim
# Out:
# 2

# %%
Dataset[["Age (X)","Blood Pressure (Y)"]].ndim
# Out:
# 2

# %% [markdown]
# # **If you want to access two Rows or n rows from Starting:**

# %%
Dataset.head(2)
# Out:
#    Age (X)  Blood Pressure (Y)
# 0     25.0               120.0
# 1     30.0               125.0

# %% [markdown]
# # **If you want to access two Rows or n rows from Ending:**

# %%
Dataset.tail(2)
# Out:
#     Age (X)  Blood Pressure (Y)
# 18      NaN               160.0
# 19    120.0               190.0
