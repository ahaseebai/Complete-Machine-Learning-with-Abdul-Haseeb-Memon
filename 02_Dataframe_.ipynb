# %% [markdown]
# <a href="https://colab.research.google.com/github/ahaseebai/Complete-Machine-Learning-with-Abdul-Haseeb-Memon/blob/main/02_Dataframe_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Numpy**

# %%
import numpy as np
df = np.array(["haseeb", "Ali","Uzair"])
df
# Out:
# array(['haseeb', 'Ali', 'Uzair'], dtype='<U6')

# %% [markdown]
# # **Dataframes:**

# %%
import pandas as pd
df = pd.DataFrame({
    "Name": ["Ali", "Ahmed"],
    "Age": [22, 24]
})
df
# Out:
#     Name  Age
# 0    Ali   22
# 1  Ahmed   24
